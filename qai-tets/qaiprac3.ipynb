# %%
import random

# Define initial state for a simple 3-puzzle, assuming 3 pegs (like Tower of Hanoi) and 3 disks
initial_state = {
    "peg1": [3, 2, 1],  # Peg 1 has all disks, 3 is the largest, 1 is the smallest
    "peg2": [],
    "peg3": []
}

# Define the goal state to solve the puzzle: all disks on peg3 in correct order
goal_state = {
    "peg1": [],
    "peg2": [],
    "peg3": [3, 2, 1]
}

# Production rules define legal moves in the 3-puzzle problem
def can_move(from_peg, to_peg, state):
    """Check if it's legal to move the top disk from one peg to another."""
    if not state[from_peg]:
        return False  # No disk to move from this peg
    if not state[to_peg]:
        return True   # Can move to an empty peg
    # Can move if the top disk on 'from_peg' is smaller than top disk on 'to_peg'
    return state[from_peg][-1] < state[to_peg][-1]

def move_disk(state, from_peg, to_peg):
    """Move the top disk from one peg to another."""
    if can_move(from_peg, to_peg, state):
        disk = state[from_peg].pop()
        state[to_peg].append(disk)
        return True
    return False

# Quantum-inspired choices: randomly select a move to simulate superposition
def quantum_choice(possible_moves):
    """Simulate quantum superposition by choosing a random valid move."""
    return random.choice(possible_moves)

def is_goal_state(state):
    """Check if the current state matches the goal state."""
    return state == goal_state

# Main Quantum Production System Solver
def quantum_3_puzzle_solver(state):
    steps = 0
    max_steps = 50  # Set a limit to avoid infinite loops
    
    while not is_goal_state(state) and steps < max_steps:
        # List all possible moves
        possible_moves = []
        for from_peg in ["peg1", "peg2", "peg3"]:
            for to_peg in ["peg1", "peg2", "peg3"]:
                if from_peg != to_peg and can_move(from_peg, to_peg, state):
                    possible_moves.append((from_peg, to_peg))
        
        # If no moves are possible, break (though this shouldn't happen in this puzzle)
        if not possible_moves:
            print("No more moves possible.")
            break
        
        # Select a quantum-inspired random move
        from_peg, to_peg = quantum_choice(possible_moves)
        
        # Apply the chosen move
        move_disk(state, from_peg, to_peg)
        
        # Print the current state
        print(f"Step {steps + 1}: Move disk from {from_peg} to {to_peg}")
        print_state(state)
        
        # Increment step counter
        steps += 1

    # Check if goal state is achieved
    if is_goal_state(state):
        print("Goal state reached!")
    else:
        print("Failed to reach the goal state within the step limit.")

def print_state(state):
    """Display the current state of the puzzle."""
    for peg in ["peg1", "peg2", "peg3"]:
        print(f"{peg}: {state[peg]}")
    print("\n")

# Run the quantum-inspired 3-puzzle solver
print("Starting 3-Puzzle Solver with Quantum-Inspired Production System...\n")
quantum_3_puzzle_solver(initial_state)
# Out:
# Starting 3-Puzzle Solver with Quantum-Inspired Production System...
#
# Step 1: Move disk from peg1 to peg3
# peg1: [3, 2]
# peg2: []
# peg3: [1]
#
#
# Step 2: Move disk from peg3 to peg2
# peg1: [3, 2]
# peg2: [1]
# peg3: []
#
#
# Step 3: Move disk from peg2 to peg1
# peg1: [3, 2, 1]
# peg2: []
# peg3: []
#
#
# Step 4: Move disk from peg1 to peg3
# peg1: [3, 2]
# peg2: []
# peg3: [1]
#
#
# Step 5: Move disk from peg1 to peg2
# peg1: [3]
# peg2: [2]
# peg3: [1]
#
#
# Step 6: Move disk from peg2 to peg1
# peg1: [3, 2]
# peg2: []
# peg3: [1]
#
#
# Step 7: Move disk from peg3 to peg2
# peg1: [3, 2]
# peg2: [1]
# peg3: []
#
#
# Step 8: Move disk from peg2 to peg1
# peg1: [3, 2, 1]
# peg2: []
# peg3: []
#
#
# Step 9: Move disk from peg1 to peg2
# peg1: [3, 2]
# peg2: [1]
# peg3: []
#
#
# Step 10: Move disk from peg2 to peg3
# peg1: [3, 2]
# peg2: []
# peg3: [1]
#
#
# Step 11: Move disk from peg3 to peg2
# peg1: [3, 2]
# peg2: [1]
# peg3: []
#
#
# Step 12: Move disk from peg2 to peg1
# peg1: [3, 2, 1]
# peg2: []
# peg3: []
#
#
# Step 13: Move disk from peg1 to peg3
# peg1: [3, 2]
# peg2: []
# peg3: [1]
#
#
# Step 14: Move disk from peg3 to peg1
# peg1: [3, 2, 1]
# peg2: []
# peg3: []
#
#
# Step 15: Move disk from peg1 to peg2
# peg1: [3, 2]
# peg2: [1]
# peg3: []
#
#
# Step 16: Move disk from peg2 to peg3
# peg1: [3, 2]
# peg2: []
# peg3: [1]
#
#
# Step 17: Move disk from peg3 to peg1
# peg1: [3, 2, 1]
# peg2: []
# peg3: []
#
#
# Step 18: Move disk from peg1 to peg3
# peg1: [3, 2]
# peg2: []
# peg3: [1]
#
#
# Step 19: Move disk from peg3 to peg2
# peg1: [3, 2]
# peg2: [1]
# peg3: []
#
#
# Step 20: Move disk from peg2 to peg3
# peg1: [3, 2]
# peg2: []
# peg3: [1]
#
#
# Step 21: Move disk from peg3 to peg2
# peg1: [3, 2]
# peg2: [1]
# peg3: []
#
#
# Step 22: Move disk from peg2 to peg3
# peg1: [3, 2]
# peg2: []
# peg3: [1]
#
#
# Step 23: Move disk from peg3 to peg2
# peg1: [3, 2]
# peg2: [1]
# peg3: []
#
#
# Step 24: Move disk from peg2 to peg1
# peg1: [3, 2, 1]
# peg2: []
# peg3: []
#
#
# Step 25: Move disk from peg1 to peg2
# peg1: [3, 2]
# peg2: [1]
# peg3: []
#
#
# Step 26: Move disk from peg1 to peg3
# peg1: [3]
# peg2: [1]
# peg3: [2]
#
#
# Step 27: Move disk from peg3 to peg1
# peg1: [3, 2]
# peg2: [1]
# peg3: []
#
#
# Step 28: Move disk from peg1 to peg3
# peg1: [3]
# peg2: [1]
# peg3: [2]
#
#
# Step 29: Move disk from peg2 to peg1
# peg1: [3, 1]
# peg2: []
# peg3: [2]
#
#
# Step 30: Move disk from peg3 to peg2
# peg1: [3, 1]
# peg2: [2]
# peg3: []
#
#
# Step 31: Move disk from peg1 to peg3
# peg1: [3]
# peg2: [2]
# peg3: [1]
#
#
# Step 32: Move disk from peg3 to peg2
# peg1: [3]
# peg2: [2, 1]
# peg3: []
#
#
# Step 33: Move disk from peg1 to peg3
# peg1: []
# peg2: [2, 1]
# peg3: [3]
#
#
# Step 34: Move disk from peg2 to peg1
# peg1: [1]
# peg2: [2]
# peg3: [3]
#
#
# Step 35: Move disk from peg1 to peg2
# peg1: []
# peg2: [2, 1]
# peg3: [3]
#
#
# Step 36: Move disk from peg2 to peg3
# peg1: []
# peg2: [2]
# peg3: [3, 1]
#
#
# Step 37: Move disk from peg2 to peg1
# peg1: [2]
# peg2: []
# peg3: [3, 1]
#
#
# Step 38: Move disk from peg3 to peg1
# peg1: [2, 1]
# peg2: []
# peg3: [3]
#
#
# Step 39: Move disk from peg1 to peg2
# peg1: [2]
# peg2: [1]
# peg3: [3]
#
#
# Step 40: Move disk from peg2 to peg1
# peg1: [2, 1]
# peg2: []
# peg3: [3]
#
#
# Step 41: Move disk from peg1 to peg2
# peg1: [2]
# peg2: [1]
# peg3: [3]
#
#
# Step 42: Move disk from peg1 to peg3
# peg1: []
# peg2: [1]
# peg3: [3, 2]
#
#
# Step 43: Move disk from peg2 to peg3
# peg1: []
# peg2: []
# peg3: [3, 2, 1]
#
#
# Goal state reached!
